# %%
import importlib
import helper_functions
importlib.reload(helper_functions)
from helper_functions import Helper

# %%
system_prompt = """
    You are a Python engineer who writes very concise code.
"""

conversation = Helper()


conversation.add_user_message(conversation.messages, "Write a python function that checks for duplicate characters.")

answer = conversation.chat(conversation.messages, system=system_prompt)

print(answer)
# Out:
# ## Duplicate Character Checker
#
# Here's a Python function that checks for duplicate characters in a string:
#
# ```python
# def check_duplicates(text: str) -> dict:
#     """
#     Checks for duplicate characters in a string.
#
#     Args:
#         text: The input string to check.
#
#     Returns:
#         A dictionary containing:
#             - 'has_duplicates': Boolean indicating if duplicates exist
#             - 'duplicates': Dictionary of duplicate characters and their counts
#     """
#     char_count = {}
#
#     # Count occurrences of each character
#     for char in text:
#         char_count[char] = char_count.get(char, 0) + 1
#
#     # Filter only duplicate characters (count > 1)
#     duplicates = {char: count for char, count in char_count.items() if count > 1}
#
#     return {
#         "has_duplicates": len(duplicates) > 0,
#         "duplicates": duplicates
#     }
#
#
# # --- Example Usage ---
# test_strings = [
#     "hello",
#     "python",
# ...
