# %%
import importlib
import helper_functions
importlib.reload(helper_functions)
from helper_functions import Helper

# %%
conversation = Helper()
while True:
    user_input = input("> ")
    print(">", user_input)

    conversation.add_user_message(conversation.messages, user_input)
    answer = conversation.chat(conversation.messages)
    conversation.add_assistant_message(conversation.messages, answer)
    print("---")
    print(answer)
    print("---")
