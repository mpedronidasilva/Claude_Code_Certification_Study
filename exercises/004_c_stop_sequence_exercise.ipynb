# %%
import importlib
import helper_functions
importlib.reload(helper_functions)
from helper_functions import Helper
import json

# %%
conversation = Helper()


conversation.add_user_message("Generate three different sample AWS CLI commands. Each should be very short.")
conversation.add_assistant_message("Here are all three commands in a single block without any comments:\n```bash")

answer = conversation.chat(stop_sequences=["```"])
answer.strip()

print(answer)
# Out:
# aws s3 ls
# aws ec2 describe-instances
# aws iam list-users

# %%
txt
# Out:
# [{'command': 'aws s3 ls', 'description': 'List all S3 buckets'},
#  {'command': 'aws ec2 describe-instances',
#   'description': 'List EC2 instances'},
#  {'command': 'aws iam list-users', 'description': 'List IAM users'}]
