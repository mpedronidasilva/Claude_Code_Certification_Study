# %%
import importlib
import exercises.helper_functions
importlib.reload(exercises.helper_functions)
from exercises.helper_functions import Helper

# %%
conversation = Helper()

conversation.add_user_message(conversation.messages, "Generate a one sentence movie idea")
answer = conversation.chat(conversation.messages)

print(answer)
# Out:
# Here's a movie idea:
#
# **A retired safecracker with dementia must rely on the muscle memory of his hands to pull off one final heist — even as his mind forgets why he started.**
