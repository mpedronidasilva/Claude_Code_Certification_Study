# %%
import importlib
import utils.helper_functions as helper_functions
importlib.reload(helper_functions)
from utils.helper_functions import DatasetGenerator

# %%
ds_g = DatasetGenerator()

ds = ds_g.generate_dataset()

with open("dataset.json", "w")as f:
    json.dump(ds, f, indent=2)

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = ds_g.run_eval(dataset)
results
# Out:
# Average score: 6.666666666666667
# [{'output': "\nimport re\n\ndef extract_s3_bucket_name(s3_uri):\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if match:\n        return match.group(1)\n    return None\n\n# Test\nprint(extract_s3_bucket_name('s3://my-bucket/path/to/file.txt'))\n",
#   'test_case': {'task': "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#    'format': 'regex',
#    'solution_criteria': 'Should correctly extract bucket names from various S3 URI formats, handling URIs with and without paths, and should not match invalid bucket names'},
#   'reasoning': "The solution works correctly for the basic use case of standard S3 URIs with the 's3://' prefix. However, it lacks robustness in two key areas: (1) it doesn't validate extracted bucket names against AWS naming constraints, potentially returning invalid bucket names, and (2) it doesn't handle alternative S3 URI formats that are common in real-world applications. The code is clean and handles the happy path well, but would benefit from input sanitization and more comprehensive format support.",
#   'score': 8.0},
#  {'output': '\nimport json\nfrom datetime import datetime\n\ndef extract_cloudwatch_log_fields(log_event):\n    """\n    Extracts timestamp and message fields from an AWS CloudWatch log event.\n    \n    Args:\n        log_event: A CloudWatch log event (dict or JSON string)\n    \n    Returns:\n        A dictionary with \'timestamp\' and \'message\' fields\n    """\n    if isinstance(log_event, str):\n        log_event = json.loads(log_event)\n    \n    result = {}\n    \n    if \'timestamp\' in log_event:\n        result[\'timestamp\'] = log_event[\'timestamp\']\n    \n    if \'message\' in log_event:\n        result[\'message\'] = log_event[\'message\']\n    \n    return result\n\n\ndef extract_cloudwatch_log_fields_advanced(log_event):\n    """\n    Extracts timestamp and message fields from various CloudWatch log event formats.\n    Handles both standard CloudWatch Logs format and Lambda log format.\n    \n    Args:\n        log_event: A CloudWatch log event (dict or JSON string)\n    \n    Returns:\n        A dictionary with \'timestamp\' and \'message\' fields\n    """\n    if isinstance(log_event, str):\n        try:\n            log_event = json.loads(log_event)\n        except json.JSONDecodeError:\n            return {\'timestamp\': None, \'message\': log_event}\n    \n    result = {}\n    \n    timestamp_keys = [\'timestamp\', \'time\', \'@timestamp\', \'ts\']\n    message_keys = [\'message\', \'msg\', \'body\', \'text\', \'log\']\n    \n    for key in timestamp_keys:\n        if key in log_event:\n            result[\'timestamp\'] = log_event[key]\n            break\n    \n    for key in message_keys:\n        if key in log_event:\n            result[\'message\'] = log_event[key]\n            break\n    \n    if \'timestamp\' not in result:\n        result[\'timestamp\'] = None\n    if \'message\' not in result:\n        result[\'message\'] = None\n    \n    return result\n',
#   'test_case': {'task': 'Write a Python function that takes an AWS CloudWatch log event and extracts the timestamp and message fields, returning them as a dictionary',
#    'format': 'python',
#    'solution_criteria': "Function should handle the standard CloudWatch Logs JSON structure, extract 'timestamp' and 'message' fields, and return a clean dictionary with these values"},
#   'reasoning': "The solution correctly addresses the core requirement of extracting timestamp and message from CloudWatch log events. The advanced function demonstrates good defensive programming by handling JSON parsing errors and multiple field name variations. However, the basic function has a critical flaw: it doesn't guarantee both keys exist in the returned dictionary, which violates the stated requirement of returning 'a dictionary with timestamp and message fields.' The lack of timestamp validation/conversion is also a missed opportunity since CloudWatch timestamps are typically epoch milliseconds that users often need converted to readable formats. The solution would be stronger if the basic function always returned both keys (with None values if missing) and if there was optional timestamp conversion functionality.",
#   'score': 8.25},
#  {'output': '\nimport json\n\niam_policy = {\n    "Version": "2012-10-17",\n    "Statement": [\n        {\n            "Effect": "Allow",\n            "Action": [\n                "s3:GetObject",\n                "s3:GetObjectVersion",\n                "s3:ListBucket"\n            ],\n            "Resource": [\n                "arn:aws:s3:::BUCKET_NAME",\n                "arn:aws:s3:::BUCKET_NAME/*"\n            ]\n        }\n    ]\n}\n\nprint(json.dumps(iam_policy, indent=2))\n',
#   'test_case': {'task': 'Create a JSON template for an AWS IAM policy that allows read-only access to a specific S3 bucket',
#    'format': 'json',
#    'solution_criteria': 'Should be valid JSON, include proper IAM policy structure with Effect, Action, and Resource fields, and grant only s3:GetObject and s3:ListBucket permissions'},
#   'reasoning': 'The solution correctly implements a read-only S3 IAM policy with valid JSON and proper AWS IAM structure. All required fields are present and the permissions are appropriately restrictive. However, the inclusion of GetObjectVersion is slightly over-permissive for a basic read-only use case, and the placeholder replacement mechanism could be more robust. The code is functional but could be more production-ready with better documentation and validation.',
#   'score': 3.75}]
